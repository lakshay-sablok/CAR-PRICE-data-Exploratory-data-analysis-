# %% [markdown]
# EXPLORATORY DATA ANALYSIS OF **CAR PRICE**
#
# *   Submitted by :- Lakshay sablok
# *   College name :- Thapar university,patiala(TIET)
# *   Email id     :- lsablok_be20@thapar.edu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/content/CarPrice.xlsx - in.csv', encoding='latin-1')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
display(pd.DataFrame(df))
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
 df.shape
# Out:
# (205, 26)

# %%
car=df['car_ID'].value_counts()
print(car)
# Out:
# 1      1
# 142    1
# 132    1
# 133    1
# 134    1
#       ..
# 72     1
# 73     1
# 74     1
# 75     1
# 205    1
# Name: car_ID, Length: 205, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
top_t=df.sample(70)
print(top_t)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 21       22          1             dodge rampage      gas        std
# 148     149          0                 subaru dl      gas        std
# 41       42          0               honda civic      gas        std
# 86       87          1         mitsubishi pajero      gas        std
# 188     189          2         volkswagen dasher      gas        std
# ..      ...        ...                       ...      ...        ...
# 78       79          2      mitsubishi outlander      gas        std
# 40       41          0              honda accord      gas        std
# 100     101          0              nissan nv200      gas        std
# 151     152          1             toyota corona      gas        std
# 122     123          1  plymouth fury gran sedan      gas        std
#
#     doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# 21         two  hatchback        fwd          front       93.7  ...
# ...

# %% [markdown]
# # ***CAR SPECIFICATIONS***

# %%
top_t=df.sample(70)
top_t
# Out:
#      car_ID  symboling                       CarName fueltype aspiration  \
# 141     142          0                        subaru      gas        std
# 183     184          2  volkswagen 1131 deluxe sedan      gas        std
# 161     162          0                toyota corolla      gas        std
# 27       28          1          dodge coronet custom      gas      turbo
# 20       21          0           chevrolet vega 2300      gas        std
# ..      ...        ...                           ...      ...        ...
# 19       20          1         chevrolet monte carlo      gas        std
# 102     103          0                   nissan fuga      gas        std
# 10       11          2                      bmw 320i      gas        std
# 192     193          0      volkswagen rabbit custom   diesel      turbo
# 155     156          0                 toyota carina      gas        std
#
#     doornumber    carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# # **CAR NAME VS PRICE**

# %%
top_t.plot(x="CarName",y="price",kind="bar")
# Out:
# <Axes: xlabel='CarName'>

# %% [markdown]
# # **FUEL TYPE**

# %%
top_t[['CarName','fueltype','price']]
# Out:
#                           CarName fueltype    price
# 141                        subaru      gas   7126.0
# 183  volkswagen 1131 deluxe sedan      gas   7975.0
# 161                toyota corolla      gas   8358.0
# 27           dodge coronet custom      gas   8558.0
# 20            chevrolet vega 2300      gas   6575.0
# ..                            ...      ...      ...
# 19          chevrolet monte carlo      gas   6295.0
# 102                   nissan fuga      gas  14399.0
# 10                       bmw 320i      gas  16430.0
# 192      volkswagen rabbit custom   diesel  13845.0
# 155                 toyota carina      gas   8778.0
#
# [70 rows x 3 columns]

# %% [markdown]
# # **FUELTYPE** :- GAS & DIESEL

# %%
fueltype=top_t['fueltype'].value_counts().head(10)
fueltype
# Out:
# gas       64
# diesel     6
# Name: fueltype, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax=sns.barplot(y=top_t['price'], x=top_t['fueltype'], palette='magma')
plt.title('Top 70 Cars FuelType prices',color='black',fontsize=30)
plt.xticks(rotation=0, fontsize=30)
plt.yticks(fontsize=30)

ax.set_xlabel('\nFUELTYPE\n', fontsize=30, color='black')
ax.set_ylabel('\nPRICE\n', fontsize=30, color='black')

ax.grid(color='black', linewidth=1, axis='y', alpha=.2)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **SYMBOLING**

# %%
top_t=df['symboling'].value_counts()
print (top_t)
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
sns.barplot(x='symboling',y='price',data=df,estimator=np.median)
# Out:
# <Axes: xlabel='symboling', ylabel='price'>

# %%
sns.boxplot(y=df['symboling'])
# Out:
# <Axes: ylabel='symboling'>

# %%
top_t=df['drivewheel'].value_counts()
print (top_t)
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
sns.barplot(x='drivewheel',y='price',data=df,estimator=np.median)
# Out:
# <Axes: xlabel='drivewheel', ylabel='price'>

# %% [markdown]
# **FUEL SYSTEM**

# %%
top_t=df['fuelsystem'].value_counts()
print (top_t)
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %% [markdown]
# **STROKE**

# %%
sns.distplot(df['stroke'])
# Out:
# <ipython-input-123-bb01eaaf5573>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['stroke'])
# <Axes: xlabel='stroke', ylabel='Density'>

# %% [markdown]
# **COMPRESSIONRATIO**

# %%
sns.distplot(df['compressionratio'])
# Out:
# <ipython-input-124-b5c7c9180a31>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['compressionratio'])
# <Axes: xlabel='compressionratio', ylabel='Density'>

# %%
sns.barplot(x='compressionratio',y='price',data=df)
# Out:
# <Axes: xlabel='compressionratio', ylabel='price'>

# %% [markdown]
# **HORSE POWER**

# %%
sns.catplot(data=df, x="horsepower", kind="box")

# %% [markdown]
# **ENGINES SIZE**

# %%
sns.catplot(data=df, x="enginesize", kind="box")

# %% [markdown]
# **HIGHWAYMPG**

# %%
sns.catplot(data=df, x="highwaympg", kind="box")

# %% [markdown]
# **CITYMPG**

# %%
sns.catplot(data=df, x="citympg", kind="box")
